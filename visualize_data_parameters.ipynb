# %%
import json
import os, glob

from itertools import product

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams

from collections import defaultdict

from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

import seaborn as sns
sns.set_style('whitegrid')

# %%
dataset_to_visualize = 'basic_toy_dataset'
split_to_visualize = 'train'

# %%
dataset_params_csv = os.path.join('data', dataset_to_visualize, split_to_visualize,
                                  'params_dataset.csv')
dataset_params_df = pd.read_csv(dataset_params_csv, index_col=0)

cols_to_drop = []
for col in dataset_params_df.columns:
    dataset_params_df[col] = dataset_params_df[col].map(lambda x: json.loads(x.replace("'", '"')))
    val = dataset_params_df.loc[0, col]
    if val['operation'] == 'None':
        cols_to_drop.append(col)

dataset_params_df.drop(cols_to_drop, axis=1, inplace=True)

# %%
def visualize_params(param_column):

    op = param_column[0]['operation']
    if op == 'mix':
        return

    param_names = list(param_column[0]['parameters'].keys())

    for p in param_names:
        vals = [c['parameters'][p] for c in param_column]
        plt.hist(vals, bins=20)
        plt.title(f"{op} {p}")
        plt.show()

    return

# %%
for col in dataset_params_df.columns:
    vals = dataset_params_df[col].values
    visualize_params(vals)

# %%
dataset_params_df.head()
# Out:
#                                               (0, 0)  \
# 0  {'operation': 'lfo', 'parameters': {'amp': 0.0...
# 1  {'operation': 'lfo', 'parameters': {'amp': 0.4...
# 2  {'operation': 'lfo', 'parameters': {'amp': 0.0...
# 3  {'operation': 'lfo', 'parameters': {'amp': 0.1...
# 4  {'operation': 'lfo', 'parameters': {'amp': 0.7...
#
#                                               (1, 0)  \
# 0  {'operation': 'lfo', 'parameters': {'amp': 0.6...
# 1  {'operation': 'lfo', 'parameters': {'amp': 0.0...
# 2  {'operation': 'lfo', 'parameters': {'amp': 0.1...
# 3  {'operation': 'lfo', 'parameters': {'amp': 0.0...
# 4  {'operation': 'lfo', 'parameters': {'amp': 0.3...
#
#                                               (0, 1)  \
# 0  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 1  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 2  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 3  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 4  {'operation': 'fm', 'parameters': {'amp_c': 0....
#
#                                               (1, 1)  \
# 0  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 1  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 2  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 3  {'operation': 'fm', 'parameters': {'amp_c': 0....
# 4  {'operation': 'fm', 'parameters': {'amp_c': 0....
#
#                                        (0, 2)  \
# 0  {'operation': 'mix', 'parameters': 'None'}
# 1  {'operation': 'mix', 'parameters': 'None'}
# 2  {'operation': 'mix', 'parameters': 'None'}
# 3  {'operation': 'mix', 'parameters': 'None'}
# 4  {'operation': 'mix', 'parameters': 'None'}
#
#                                               (0, 3)
# 0  {'operation': 'filter', 'parameters': {'filter...
# 1  {'operation': 'filter', 'parameters': {'filter...
# 2  {'operation': 'filter', 'parameters': {'filter...
# 3  {'operation': 'filter', 'parameters': {'filter...
# 4  {'operation': 'filter', 'parameters': {'filter...
